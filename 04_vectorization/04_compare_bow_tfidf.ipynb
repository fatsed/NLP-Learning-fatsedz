# %%
import pandas as pd

data = {
    "text": [
        "I love this movie, it is amazing",
        "This film was terrible and boring",
        "What a great and wonderful story",
        "I hate this, so bad and awful",
        "Absolutely fantastic acting",
        "The worst movie I have ever seen"
    ],
    "label": [1, 0, 1, 0, 1, 0]  # 1=positive, 0=negative
}

df = pd.DataFrame(data)
df
# Out:
#                                 text  label
# 0   I love this movie, it is amazing      1
# 1  This film was terrible and boring      0
# 2   What a great and wonderful story      1
# 3      I hate this, so bad and awful      0
# 4        Absolutely fantastic acting      1
# 5   The worst movie I have ever seen      0

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df["text"], df["label"], test_size=0.3, random_state=42
)

# BoW
cv = CountVectorizer()
X_train_bow = cv.fit_transform(X_train)
X_test_bow = cv.transform(X_test)

clf_bow = MultinomialNB()
clf_bow.fit(X_train_bow, y_train)
y_pred_bow = clf_bow.predict(X_test_bow)

print("Accuracy (BoW):", accuracy_score(y_test, y_pred_bow))
# Out:
# Accuracy (BoW): 0.5

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

clf_tfidf = MultinomialNB()
clf_tfidf.fit(X_train_tfidf, y_train)
y_pred_tfidf = clf_tfidf.predict(X_test_tfidf)

print("Accuracy (TF-IDF):", accuracy_score(y_test, y_pred_tfidf))
# Out:
# Accuracy (TF-IDF): 0.5
