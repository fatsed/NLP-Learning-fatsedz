# %%
import matplotlib.pyplot as plt
x = [1, 2, 43, 5, 7, 13, 14]
y = [10, 15, 20, 25, 30, 35, 40]
plt.plot(x, y)
plt.show()

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random
def random_color(*args, **kwargs):
  colors = ["#134686", "#ED3F27", "#FEB21A", "#636CCB"]
  return random.choice(colors)

text="""Python is powerful and simple.
Artificial Intelligence changes the world.
Data Science is the future.
Machine Learning makes systems smart.
Deep Learning uses neural networks.
"""
wordcloud=WordCloud(width=800, height=400, background_color='#F5F1DC', color_func=random_color).generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from google.colab import files
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import random
def random_color(*args, **kwargs):
  colors = ["#34656D", "#FAEAB1", "#FAF8F1"]
  return random.choice(colors)

uploaded_file=files.upload()

for i in uploaded_file.keys():
  print("You uploaded file:", i)

font_name=list(uploaded_file.keys())[0]
font_pa=f"/content/{font_name}"
print("font path is:", font_pa)


text="""
پایتون زبانی ساده و قدرتمند است.
یادگیری پایتون دریچه‌ای به دنیای هوش مصنوعی باز می‌کند.
تحلیل داده را آسان می‌کنند.
یادگیری ماشین و شبکه‌های عصبی با پایتون جان می‌گیرند.
پایتون انتخاب محبوب دانشمندان داده و پژوهشگران است.
جامعه کاربری بزرگ پایتون همیشه آماده کمک و یادگیری است.
با پایتون می‌توان وب‌سایت، بازی و برنامه‌های هوشمند ساخت.
سادگی پایتون الهام‌بخش برنامه‌نویسان تازه‌کار است.

"""
wordcloud=WordCloud(width=1200, height=400, background_color='#334443', color_func=random_color, font_path=font_pa).generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
#      <input type="file" id="files-80bae0a0-c924-45eb-a5e2-4c67f6d36fd0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80bae0a0-c924-45eb-a5e2-4c67f6d36fd0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
def random_color(*args, **kwargs):
    colors = ["#34656D", "#FAEAB1", "#FAF8F1"]
    return random.choice(colors)


uploaded_files = files.upload()
font_names = [k for k in uploaded_files.keys() if k.lower().endswith(".ttf")]
print("Uploaded fonts:")
for i, n in enumerate(font_names):
    print(f"{i}: {n}")

# ---- choose font ----
if len(font_names) == 0:
    raise RuntimeError("No font uploaded. Upload at least one .ttf that supports Persian.")
elif len(font_names) == 1:
    fa_idx = en_idx = 0
else:
    try:
        fa_idx = int(input("Enter index of font for Farsi: "))
        en_idx = int(input("Enter index of font for English: "))
    except Exception:
        fa_idx, en_idx = 0, 1

fa_idx = max(0, min(fa_idx, len(font_names)-1))
en_idx = max(0, min(en_idx, len(font_names)-1))

font_fa = f"/content/{font_names[fa_idx]}"
font_en = f"/content/{font_names[en_idx]}"


text_fa = """
پایتون زبانی ساده و قدرتمند است.
هوش مصنوعی جهان را تغییر می‌دهد.
یادگیری ماشین سیستم‌ها را هوشمند می‌کند.
کتابخانه‌های پایتون تحلیل داده را آسان می‌کنند.
"""
text_en = """Python is powerful and simple.
Artificial Intelligence changes the world.
Machine Learning makes systems smart.
Data Science is the future.
"""

# ---- generate word clouds ----
wc_kwargs = dict(width=600, height=400, background_color='#F5F1DC', color_func=random_color)
wordcloud_fa = WordCloud(font_path=font_fa, **wc_kwargs).generate(text_fa)
wordcloud_en = WordCloud(font_path=font_en, **wc_kwargs).generate(text_en)

fig, axs = plt.subplots(1, 2, figsize=(15,6))
axs[0].imshow(wordcloud_en, interpolation="bilinear"); axs[0].axis("off"); axs[0].set_title("English Word Cloud")
axs[1].imshow(wordcloud_fa, interpolation="bilinear"); axs[1].axis("off"); axs[1].set_title("Farsi Word Cloud")
plt.show()
# Out:
#      <input type="file" id="files-1026702d-d824-4e63-b001-f65c7428cf75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1026702d-d824-4e63-b001-f65c7428cf75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

img = Image.open("/content/sphx_glr_masked_002.png").convert("L")

mask = np.array(img)
mask = np.where(mask > 128, 255, 0).astype("uint8")

ys, xs = np.where(mask == 0)
x_min, x_max = xs.min(), xs.max()
y_min, y_max = ys.min(), ys.max()
mask_cropped = mask[y_min:y_max+1, x_min:x_max+1]

alice_mask_img = Image.fromarray(mask_cropped)
alice_mask_img = alice_mask_img.resize((800, 800))
alice_mask = np.array(alice_mask_img)

text = """
NLP, or Natural Language Processing, is a branch of artificial intelligence
that allows computers to understand, interpret, and generate human language.
It combines linguistics, computer science, and machine learning to build
applications such as chatbots, translators, and sentiment analysis tools.
NLP, or Natural Language Processing, is a branch of artificial intelligence
that allows computers to understand, interpret, and generate human language.
It combines linguistics, computer science, and machine learning to build
applications such as chatbots, translators, and sentiment analysis tools.
"""

stopwords = set(STOPWORDS)

wc = WordCloud(
    background_color="white",
    max_words=2000,
    mask=alice_mask,
    stopwords=stopwords,
    contour_width=3,
    contour_color="steelblue",
    colormap="viridis"
)

wc.generate(text)

plt.figure(figsize=(6, 6))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()

wc.to_file("/content/wordcloud_alice_style.png")
print("✅ ذخیره شد: /content/wordcloud_alice_style.png")
# Out:
# ✅ ذخیره شد: /content/wordcloud_alice_style.png

# %%
# !pip install gensim python-crfsuite fasttext flashtext && pip install hazm --no-deps
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-3.0.1-py3-none-any.whl.metadata (10.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 77.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.3 MB/s eta 0:00:00
# Using cached pybind11-3.0.1-py3-none-any.whl (293 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp312-cp312-linux_x86_64.whl size=4498212 sha256=4dc8e866ed0060584c825aa81f8d5bc543aca408e4276e18015ee1bb1c4777bf
#   Stored in directory: /root/.cache/pip/wheels/20/27/95/a7baf1b435f1cbde017cabdf1e9688526d2b0e929255a359c6
# ...
#   Created wheel for flashtext: filename=flashtext-2.7-py2.py3-none-any.whl size=9300 sha256=0141ebab307866c2d9ca32d61ccb7f71f827733a8821cb2bb6f7b5211380fd5c
# ...

# %%
from wordcloud import WordCloud
from google.colab import files
import matplotlib.pyplot as plt
from hazm import stopwords_list, word_tokenize

text = '''
پردازش زبان طبیعی (NLP) یک شاخه از هوش مصنوعی است که به کامپیوترها امکان می‌دهد...
'''

# Upload font
uploaded = files.upload()
font_path = list(uploaded.keys())[0]

# Stopwords
fa_stops = set(stopwords_list())
extra_stops = {"است", "را", "که", "می‌شود", "می‌کند", "برای", "با", "این"}
fa_stops |= extra_stops

# Tokenize + clean
tokens = word_tokenize(text)
clean_text = " ".join([t for t in tokens if t not in fa_stops])

# Create word cloud
word_cloud = WordCloud(
    width=800,
    height=400,
    background_color='#d9d5fc',
    font_path=font_path,
    colormap='viridis'
).generate(clean_text)

# Show
plt.figure(figsize=(12, 6))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# Save
word_cloud.to_file("wordcloud_fa.png")
# Out:
#      <input type="file" id="files-48a081bc-ee87-4729-aac6-ec08a80b7a53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48a081bc-ee87-4729-aac6-ec08a80b7a53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
