# %%
#1: Kaggle API

# %%
# !pip install kaggle

# %%
#kaggle.com --> Account ---> API ---> Create New API Token

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-39bb3a0d-a17f-48a0-9a1d-800b4b4f4752" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39bb3a0d-a17f-48a0-9a1d-800b4b4f4752">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.makedirs("/root/.kaggle", exist_ok=True)
os.replace("kaggle.json", "/root/.kaggle/kaggle.json")
os.chmod("/root/.kaggle/kaggle.json", 600)

# %%
# !kaggle datasets download -d mohankrishnathalla/mobile-reviews-sentiment-and-specification -p ./data_kaggle_api
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mohankrishnathalla/mobile-reviews-sentiment-and-specification
# License(s): CC0-1.0
# ...
#   0% 0.00/2.11M [00:00<?, ?B/s]
# 100% 2.11M/2.11M [00:00<00:00, 588MB/s]

# %%
import zipfile
import os
zip_path = "./data_kaggle_api/mobile-reviews-sentiment-and-specification.zip"
with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall("./data_kaggle_api/mobile_reviews")
print(os.listdir("./data_kaggle_api/mobile_reviews"))
# Out:
# ['Mobile Reviews Sentiment.csv']

# %%
import pandas as pd
csv_path = "./data_kaggle_api/mobile_reviews/Mobile Reviews Sentiment.csv"
df = pd.read_csv(csv_path)
df.head()
# Out:
#    review_id      customer_name  age     brand          model  price_usd  \
# 0          1      Aryan Maharaj   45    Realme  Realme 12 Pro     337.31
# 1          2  Davi Miguel Sousa   18    Realme  Realme 12 Pro     307.78
# 2          3        Pahal Balay   27    Google        Pixel 6     864.53
# 3          4       David Guzman   19    Xiaomi  Redmi Note 13     660.94
# 4          5          Yago Leão   38  Motorola        Edge 50     792.13
#
#   price_local currency  exchange_rate_to_usd  rating  ... verified_purchase  \
# 0   ₹27996.73      INR                 83.00       2  ...              True
# 1   R$1754.35      BRL                  5.70       4  ...              True
# 2   ₹71755.99      INR                 83.00       4  ...              True
# 3  د.إ2425.65      AED                  3.67       3  ...             False
# 4   R$4515.14      BRL                  5.70       3  ...              True
#
# ...

# %%
#2: Kaggle API

# %%
# !pip install kagglehub

# %%
import kagglehub
path = kagglehub.dataset_download("mohankrishnathalla/mobile-reviews-sentiment-and-specification")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'mobile-reviews-sentiment-and-specification' dataset.
# Path to dataset files: /kaggle/input/mobile-reviews-sentiment-and-specification

# %%
import os
print(os.listdir(path))
# Out:
# ['Mobile Reviews Sentiment.csv']

# %%
import pandas as pd
import os

files = os.listdir(path)
print(files)
csv_file = [f for f in files if f.endswith(".csv")][0]  # اولین CSV
csv_path = os.path.join(path, csv_file)
df = pd.read_csv(csv_path)
df.head()
# Out:
# ['Mobile Reviews Sentiment.csv']
#    review_id      customer_name  age     brand          model  price_usd  \
# 0          1      Aryan Maharaj   45    Realme  Realme 12 Pro     337.31
# 1          2  Davi Miguel Sousa   18    Realme  Realme 12 Pro     307.78
# 2          3        Pahal Balay   27    Google        Pixel 6     864.53
# 3          4       David Guzman   19    Xiaomi  Redmi Note 13     660.94
# 4          5          Yago Leão   38  Motorola        Edge 50     792.13
#
#   price_local currency  exchange_rate_to_usd  rating  ... verified_purchase  \
# 0   ₹27996.73      INR                 83.00       2  ...              True
# 1   R$1754.35      BRL                  5.70       4  ...              True
# 2   ₹71755.99      INR                 83.00       4  ...              True
# 3  د.إ2425.65      AED                  3.67       3  ...             False
# 4   R$4515.14      BRL                  5.70       3  ...              True
#
# ...
