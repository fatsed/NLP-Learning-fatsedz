# %%
import requests as rq

payload = {
    'country': 'United States',
    'name': 'tech'
}

r = rq.get('http://universities.hipolabs.com/search', params=payload)

print(r.json()[:3])
# Out:
# [{'name': 'Tennessee Technological University', 'country': 'United States', 'state-province': None, 'domains': ['tntech.edu'], 'alpha_two_code': 'US', 'web_pages': ['http://www.tntech.edu/']}, {'name': 'Lawrence Technological University', 'country': 'United States', 'state-province': None, 'domains': ['ltu.edu'], 'alpha_two_code': 'US', 'web_pages': ['http://www.ltu.edu/']}, {'name': 'Michigan Technological University', 'country': 'United States', 'state-province': None, 'domains': ['mtu.edu'], 'alpha_two_code': 'US', 'web_pages': ['http://www.mtu.edu/']}]

# %%
print(r.status_code)
print(r.text)
print(r.json())
# Out:
# 200
# ...
